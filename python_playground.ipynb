# %%
print("Hello, brave soldier, I see you are coming near this horrible dungeon, you are about to risk, life and limb in this dangeroous place")
print(" ")
print("what is your name, I will tell the others about your valiant efforts")

name = input()

print(" ")
print("Nice to meet you " + name + "  go forth and Godspeed, may the lord be with you")
print(" ")
print("Would you like to enter this dungeon and change you fate forever? Yes/No")

enter = input()

if(enter == "Yes") :
    print(" ")
    print("!!!!You have Entered the Dungeon!!!!!!")
else :
    print(" ")
    print("You didn't enter the dungeon")

print("A Dragon has appeared before you, how will you defend yourself Sword/Shield........")
weapon = input()
if(weapon == "Sword") :
    print("You have picked up a rusty sword")
else :
    print("You prepare to defend yourself from the mighty dragon with a Shield")
# Out:
# Hello, brave soldier, I see you are coming near this horrible dungeon, you are about to risk, life and limb in this dangeroous place
# what is your name, I will tell the others about your valiant efforts
# Nice to meet you Rico The Brave  go forth and Godspeed, may the lord be with you
# Would you like to enter this dungeon and change you fate forever? Yes/No
# !!!!You have Entered the Dungeon!!!!!!
