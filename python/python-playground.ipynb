# %% [markdown]
# Python Lesson 1

# %% [markdown]
# $F = ma$

# %% [markdown]
# $f(m,a) = m * a$

# %% [markdown]
# $Newton Second Law Calculation(mass, acceleration) = $

# %%
def Newton_Second_Law_Calculation(mass, acceleration) :
    return mass * acceleration;

# %%
print(Newton_Second_Law_Calculation(2, 5));
print(Newton_Second_Law_Calculation(3, 8));
print(Newton_Second_Law_Calculation(6, 521));
print(Newton_Second_Law_Calculation(123, 5));
# Out:
# 10
# 24
# 3126
# 615

# %% [markdown]
# $print$

# %%
print(234);

print("Hello Rico");

print(2.456);
# Out:
# 234
# Hello Rico
# 2.456
